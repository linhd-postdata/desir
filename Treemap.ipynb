# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from collections import Counter

def read_csv(path):
    """
    :param path: of desir the xlsx file
    :return: String that contains all project descriptions
    """
    df = pd.read_csv(path)
    filtered_df = df.replace(np.nan, '-', regex=True)
    
    
    return filtered_df

# %%
proyectos = read_csv("data/mapeo_proyectos.csv")

# %%
mini = proyectos["Fuente de información"]
mini
# Out:
# 0             Congresos Humanidades Digitales Hispánicas
# 1             Congresos Humanidades Digitales Hispánicas
# 2             Congresos Humanidades Digitales Hispánicas
# 3             Congresos Humanidades Digitales Hispánicas
# 4             Congresos Humanidades Digitales Hispánicas
#                              ...
# 479                     Agencia Estatal de Investigación
# 480                     Agencia Estatal de Investigación
# 481    Jornada: Proyectos de humanidades digitales en...
# 482    Jornada: Proyectos de humanidades digitales en...
# 483                                       Fundación BBVA
# Name: Fuente de información, Length: 484, dtype: object

# %%
sources_list = mini.tolist()
for item in sources_list:
    print(item)
# Out:
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Fuente propia
# Fuente propia
# Fuente propia
# Fuente propia
# Fuente propia
# Fuente propia
# Fuente propia
# Fuente propia
# Fuente propia
# Fuente propia
# Fuente propia
# Fuente propia
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Agencia Estatal de Investigación
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Proyectos MediaLab UGR
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Red Knowmetrics
# Agencia Estatal de Investigación
# Fundación BBVA
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# ARACNE
# ARACNE
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Bibliografía
# Congreso Territorio digitales
# Red Knowmetrics
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Fundación BBVA
# Agencia Estatal de Investigación
# Fundación BBVA
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# GrinUGR
# ARACNE, BIDISO
# ARACNE, BIDISO
# ARACNE, BIDISO
# Proyecto ReMetCa
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# ARACNE
# ARACNE
# ARACNE
# ARACNE, BIDISO
# ARACNE, BIDISO
# ARACNE, BIDISO
# ARACNE, BIDISO
# ARACNE, BIDISO
# ARACNE, BIDISO
# ARACNE, BIDISO
# ARACNE, BIDISO
# Agencia Estatal de Investigación
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Fundación BBVA
# Agencia Estatal de Investigación
# Fundación BBVA
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# BIDISO
# Agencia Estatal de Investigación
# Biblioteca Virtual Miguel de Cervantes
# Biblioteca Virtual Miguel de Cervantes
# Agencia Estatal de Investigación
# Biblioteca Virtual Miguel de Cervantes
# Fundación BBVA
# Fundación BBVA
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Proyectos MediaLab UGR
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Proyectos MediaLab UGR
# Congreso Territorio digitales
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# GrinUGR
# GrinUGR
# GrinUGR
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Agencia Estatal de Investigación
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Web personal, GrinUGR
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Agencia Estatal de Investigación
# Fundación BBVA
# Red Knowmetrics
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# -
# Agencia Estatal de Investigación
# Fundación BBVA
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Congresos Humanidades Digitales Hispánicas
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# I Jornada científico-técnica en Humanidades Digitales en el CSIC
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Fundación BBVA
# Agencia Estatal de Investigación
# Proyectos subvencionados RecerCaixa
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Web personal
# Agencia Estatal de Investigación
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# I EDICIÓN DE LOS PREMIOS HDH 2018
# I EDICIÓN DE LOS PREMIOS HDH 2018
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# Agencia Estatal de Investigación
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# Agencia Estatal de Investigación
# Fundación BBVA
# Agencia Estatal de Investigación
# Proyectos subvencionados RecerCaixa
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Fundación BBVA, Red Knowmetrics
# Fundación BBVA
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Red Knowmetrics
# Red Knowmetrics
# Fuente propia
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# GrinUGR
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Bibliografía
# Google
# Proyectos subvencionados RecerCaixa
# Proyectos subvencionados RecerCaixa
# Google
# Agencia Estatal de Investigación
# Bibliografía
# Red Knowmetrics, Google
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# Web personal
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Proyectos subvencionados RecerCaixa
# I Jornada científico-técnica en Humanidades Digitales en el CSIC
# Fundación BBVA
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# Fundación BBVA
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Fuente propia
# Fuente propia
# BIDISO
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# ARACNE
# Fundación BBVA
# Proyectos subvencionados RecerCaixa
# Proyectos subvencionados RecerCaixa
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Congreso Territorio digitales
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# I Jornada científico-técnica en Humanidades Digitales en el CSIC
# Biblioteca Virtual Miguel de Cervantes
# Red Knowmetrics
# Agencia Estatal de Investigación
# Seminario Historia y Humanidades Digitales UCLM 2017
# Seminario Historia y Humanidades Digitales UCLM 2017
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Proyecto Andrés de Poza
# Agencia Estatal de Investigación
# Red Knowmetrics
# Red Knowmetrics
# Fuente propia
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Proyectos MediaLab UGR
# Fundación BBVA
# Proyectos subvencionados RecerCaixa
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Google
# Agencia Estatal de Investigación
# Proyectos subvencionados RecerCaixa
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Fundación BBVA
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Fundación BBVA
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Red Knowmetrics
# Fuente propia
# Fuente propia
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# ARACNE
# CORDIS (EU research results)
# CORDIS (EU research results)
# CORDIS (EU research results)
# CORDIS (EU research results)
# CORDIS (EU research results)
# CORDIS (EU research results)
# CORDIS (EU research results)
# I Jornada científico-técnica en Humanidades Digitales en el CSIC
# Red Knowmetrics
# Proyectos MediaLab UGR
# GrinUGR
# GrinUGR
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Congresos Humanidades Digitales Hispánicas
# Google
# Agencia Estatal de Investigación
# Fundación BBVA
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Congresos Humanidades Digitales Hispánicas
# Fundación BBVA
# Red Knowmetrics
# I Jornada científico-técnica en Humanidades Digitales en el CSIC
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: VISIBILIDAD Y DIFUSIÓN DE LA INVESTIGACIÓN
# Red Knowmetrics
# Red Knowmetrics
# Congreso Territorio digitales
# Congreso Territorio digitales
# Congreso Territorio digitales
# Congreso Territorio digitales
# Proyecto Andrés de Poza
# Diarium (USAL)
# Proyectos subvencionados RecerCaixa
# Fuente propia
# Fuente propia
# Fuente propia
# Fuente propia
# Fuente propia
# Fuente propia
# Agencia Estatal de Investigación
# Congreso Territorio digitales
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Agencia Estatal de Investigación
# Proyectos subvencionados RecerCaixa
# Proyectos subvencionados RecerCaixa
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Red Knowmetrics
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Biblioteca Virtual Miguel de Cervantes
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Proyectos subvencionados RecerCaixa
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Bibliografía
# Bibliografía
# Bibliografía
# Agencia Estatal de Investigación
# Proyectos subvencionados RecerCaixa
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Agencia Estatal de Investigación
# Jornada: Proyectos de humanidades digitales en la BNE
# Jornada: Proyectos de humanidades digitales en la BNE
# Fundación BBVA

# %%
sources_list = mini.tolist()
def_list = []
for item in sources_list:
    if "," in item:
        comas = item.split(", ")
        for element in comas:
            def_list.append(element.strip())
    else: 
        def_list.append(item.strip())

# %%
counter = Counter(def_list).most_common()

# %%
sources_dict = dict(counter)

# %%
keys = sources_dict.keys()
values = sources_dict.values()

# %% [markdown]
# # Print treemap

# %%
import squarify

# %%
#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 16)
colors = ["red", "tan", "green", "blue", "grey", "gold", "violet", "pink", "cyan", "indigo"]
squarify.plot(sizes=values, label=keys, color=colors, alpha=.5, text_kwargs={'fontsize':8})
plt.title("Fuentes de información",fontsize=23,fontweight="bold")

plt.axis('off')
plt.show()

# %% [markdown]
# # Print table

# %%
sources_table = pd.DataFrame.from_dict(sources_dict, orient='index')
sources_table
# Out:
#                                                       0
# Agencia Estatal de Investigación                    227
# Congresos Humanidades Digitales Hispánicas           56
# Jornada: Proyectos de humanidades digitales en ...   33
# Fuente propia                                        24
# Fundación BBVA                                       22
# ARACNE                                               18
# Red Knowmetrics                                      16
# CONGRESO INTERNACIONAL HUMANIDADES DIGITALES: V...   14
# Proyectos subvencionados RecerCaixa                  14
# BIDISO                                               13
# Congreso Territorio digitales                         8
# GrinUGR                                               8
# CORDIS (EU research results)                          7
# Bibliografía                                          6
# Proyectos MediaLab UGR                                5
# Biblioteca Virtual Miguel de Cervantes                5
# I Jornada científico-técnica en Humanidades Dig...    5
# Google                                                5
# Web personal                                          3
# I EDICIÓN DE LOS PREMIOS HDH 2018                     2
# Seminario Historia y Humanidades Digitales UCLM...    2
# Proyecto Andrés de Poza                               2
# Proyecto ReMetCa                                      1
# -                                                     1
# Diarium (USAL)                                        1
