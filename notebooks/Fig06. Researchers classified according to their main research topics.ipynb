# %% [markdown]
# # Fig06. Researchers classified according to their main research topics, up to five each.

# %% [markdown]
# #### Import libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.style.use('seaborn-muted')

def read_csv(path):
    """
    :param path: of desir the xlsx file
    :return: String that contains all project descriptions
    """
    df = pd.read_csv(path)
    filtered_df = df.fillna(0)
    
    
    return filtered_df

# %% [markdown]
# #### Define researchers and projects data path

# %%
file_path_i = "../data/mapeo_investigadores.csv"

# %% [markdown]
# #### Define function to clean researchers data

# %%
def prepare_data(investigadores, num_of_topics):
    investigadores = read_csv(file_path_i)
    mini = investigadores[["Temas de investigación","ID investigador"]]
    mini = mini.drop_duplicates(subset ="ID investigador", keep = "first") 
    mini.columns = ["tema", "id"]
    mini = mini.loc[mini["tema"]!=0]
    # split Research topics in rows with " | "
    filtered_df = mini.loc[mini["tema"].str.contains(' \|')]
    mini = mini.loc[mini["tema"].str.contains('\|') != True]
    new_discp = []
    for row in filtered_df.itertuples():
        for tema in row.tema.split(" | "):
            new_discp.append([tema, row.id])
    fix_df = pd.DataFrame(new_discp, columns=["tema", "id"])
    mini = mini.append(fix_df)
    del_temas = ["Arqueología del paisaje", "Ciencias de la educación", "Diseño, organización y gestión de proyectos"]
    mini = mini[~mini['tema'].isin(del_temas)]
    mini.loc[mini.tema == 'SIG y análisis geoespacial', 'tema'] = "SIG y análisis espacial"
    
    grouped = mini.groupby("tema")
    df_investigadores = grouped.count().sort_values(by=['id'], ascending=False)
    
    
    return df_investigadores

# %% [markdown]
# #### Function to translate disciplinary backgrounds

# %%
def translate(dataframe, column_to_translate, translations_filename):    
    translations_df = pd.read_csv(f"../data/{translations_filename}", sep=';')
    translations_df.columns=["tema", "research_topic"]
    df_def = pd.merge(dataframe, translations_df, on=column_to_translate, how='outer', validate="one_to_many")
    return df_def

# %% [markdown]
# #### Run program
# ## Change 'num_of_topics' to show as many research topics as you want

# %%
num_of_topics = 37
investigadores = read_csv(file_path_i)
df2 = prepare_data(investigadores, num_of_topics)
df2 = translate(df2, "tema", "temas.csv")

# %% [markdown]
# #### Print horizontal bar plot

# %%
plt.figure()
ax = df2.head(num_of_topics).plot.bar(x="research_topic", figsize=(16,6), legend=False)
ax.set_ylabel("")
ax.set_xlabel("")
# ax.xaxis.tick_top() 
plt.grid(axis='y')
plt.show()

# %% [markdown]
# #### Print table

# %%
df2
# Out:
#                                                tema   id  \
# 0                     Estudios literarios digitales  119
# 1                              Comunicación digital   65
# 2                             Bibliotecas digitales   63
# 3   Archivos digitales, repositorios y preservación   60
# 4                             Lingüística y lenguas   59
# 5                                    Bases de datos   51
# 6              Ciencias y Técnicas Historiográficas   51
# 7                                Patrimonio digital   46
# 8                                              GLAM   36
# 9                             Actividades de corpus   30
# 10                        Lingüística computacional   30
# 11                  Minado de datos/Minado de texto   28
# 12             Digitalización, creación de recursos   22
# 13              Análisis de interfaces y tecnología   22
# 14                                       Traducción   22
# 15                                  Medios sociales   21
# 16                          SIG y análisis espacial   18
# 17                                   Artes visuales   18
# 18                             Análisis de imágenes   12
# 19                Análisis de contenido audiovisual   10
# 20                                 Historia digital    9
# 21                                Modelado de datos    9
# 22                                    Web semántica    8
# 23                      Recuperación de información    7
# 24                                Análisis de redes    7
# 25                                       Sociología    7
# 26                                      Videojuegos    6
# 27        Métodos bibliográficos/estudios textuales    6
# 28                                       Hipertexto    6
# 29                               Análisis semántico    6
# 30                                          XML/TEI    6
# 31                     Realidad virtual y aumentada    5
# 32                                     Estilometría    4
# 33                                    Crowdsourcing    3
# 34                             Técnicas webmétricas    3
# 35               Aplicaciones y diseño para móviles    3
# 36                                   Geolingüística    2
# 37          Tecnologías de aprendizaje colaborativo    2
# 38                          Inteligencia Artificial    1
# 39                              Museografía virtual    1
# 40                                              OCR    1
# 41                                        Epigrafía    1
# 42                            Cursos masivos (MOOC)    1
# 43                             Aprendizaje profundo    1
#
#                            research_topic
# 0                Digital Literary Studies
# 1                   Digital communication
# 2                       Digital libraries
# 3   Digital repositories and preservation
# 4               Linguistics and languages
# 5                               Databases
# 6              Historiographic Techniques
# 7                        Digital heritage
# 8                                    GLAM
# 9                      Corpus linguistics
# 10              Computational Linguistics
# 11                            Text Mining
# 12    Digitisation, creation of resources
# 13      Interface analysis and technology
# 14                            Translation
# 15                           Social Media
# 16               GIS and spatial analysis
# 17                            Visual Arts
# 18                         Image analysis
# 19        Analysis of audiovisual content
# 20                        Digital History
# 21                         Data modelling
# 22                           Semantic Web
# 23                  Information retrieval
# 24                       Network Analysis
# 25                              Sociology
# 26                            Video games
# 27     Bibliographic methods/text studies
# 28                             Hypertexts
# 29                      Semantic analysis
# 30                                XML/TEI
# 31          Virtual and Augmented Reality
# 32                             Stylometry
# 33                          Crowdsourcing
# 34                   Webmetric techniques
# 35         Mobile applications and design
# 36                        Geo-linguistics
# 37    Collaborative learning technologies
# 38                                    NaN
# 39                         Virtual Museum
# 40                                    NaN
# 41                                    NaN
# 42                                    NaN
# 43                                    NaN
